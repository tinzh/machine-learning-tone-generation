# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
import tensorflow.keras.callbacks as callback

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')
y_train = tf.keras.utils.to_categorical(y_train,  10)

# %%
model1 = Sequential()
model1.add(Conv2D(20, (5, 5), input_shape=(28, 28, 1), activation="relu"))
model1.add(MaxPooling2D((2, 2)))
model1.add(Flatten())
model1.add(Dense(100, activation="relu"))
model1.add(Dense(10, activation="softmax"))

# %%
model1.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model1.fit(x_train, y_train)
# Out:
# Epoch 1/1
# 18208/60000 [========>.....................] - ETA: 36s - loss: 14.5654 - acc: 0.0962
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e5364d3f76af> in <module>()
# ----> 1 model1.fit(x_train, y_train)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1361           initial_epoch=initial_epoch,
#    1362           steps_per_epoch=steps_per_epoch,
# -> 1363           validation_steps=validation_steps)
#    1364
#    1365   def evaluate(self,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit_loop(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     262           ins_batch[i] = ins_batch[i].toarray()
#     263
# --> 264         outs = f(ins_batch)
#     265         if not isinstance(outs, list):
#     266           outs = [outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    2912       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    2913
# -> 2914     fetched = self._callable_fn(*array_vals)
#    2915     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2916     return fetched[:len(self.outputs)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model2 = Sequential()
model2.add(Conv2D(20, (5, 5), input_shape=(28, 28, 1), activation="relu"))
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(40, (5, 5), activation="relu"))
model2.add(MaxPooling2D((2, 2)))
model2.add(Flatten())
model2.add(Dense(1000, activation="relu"))
# model2.add(Dropout(0.25))
model2.add(Dense(1000, activation="relu"))
# model2.add(Dropout(0.25))
model2.add(Dense(10, activation="softmax"))

model2.compile(optimizer="adam",
               loss="categorical_crossentropy", 
               metrics=["accuracy"])

# %%
model2.fit(x_train, y_train, validation_split=0.33, batch_size=64, epochs=100, callbacks=[callback.ModelCheckpoint("weights.{epoch:02d}-{val_loss:.2f}.hdf5"),
                          callback.ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.001)])
# Out:
# Train on 40199 samples, validate on 19801 samples
# Epoch 1/100
# 40199/40199 [==============================] - 8s 198us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 2/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 3/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 4/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 5/100
# 40199/40199 [==============================] - 8s 188us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 6/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 7/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 8/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 9/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 10/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 11/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 12/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 13/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 14/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 15/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 16/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 17/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 18/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 19/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 20/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 21/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 22/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 23/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 24/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 25/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 26/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 27/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 28/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 29/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 30/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 31/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 32/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 33/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 34/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 35/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 36/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 37/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 38/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 39/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 40/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 41/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 42/100
# 40199/40199 [==============================] - 8s 194us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 43/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 44/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 45/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 46/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 47/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 48/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 49/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 50/100
# 40199/40199 [==============================] - 8s 193us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 51/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 52/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 53/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 54/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 55/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 56/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 57/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 58/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 59/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 60/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 61/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 62/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 63/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 64/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 65/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 66/100
# 40199/40199 [==============================] - 8s 188us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 67/100
# 40199/40199 [==============================] - 8s 187us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 68/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 69/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 70/100
# 40199/40199 [==============================] - 8s 189us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 71/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 72/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 73/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 74/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 75/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 76/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 77/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 78/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 79/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 80/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 81/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 82/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 83/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 84/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 85/100
# 40199/40199 [==============================] - 8s 192us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 86/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 87/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 88/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 89/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 90/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 91/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 92/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 93/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 94/100
# 40199/40199 [==============================] - 8s 191us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 95/100
# 40199/40199 [==============================] - 8s 190us/step - loss: 14.5355 - acc: 0.0982 - val_loss: 14.5096 - val_acc: 0.0998
# Epoch 96/100
# 35584/40199 [=========================>....] - ETA: 0s - loss: 14.5355 - acc: 0.0982
